# %%
from str_to_img import *
from img_to_bin import *
from bin_to_img import *
from dump_sprites import *
from PIL import Image
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img = str_to_img("Rugged Road", "test.png")
display(img.resize((800, 160), Image.Resampling.NEAREST))
# Out:
# <PIL.Image.Image image mode=L size=800x160>

# %%
a = img_to_bin(img, width=80, height=16, frames=1)
b = bin_to_img(a, width=80, height=16, frames=1, inverted=True)
display(b.resize((800, 160), Image.Resampling.NEAREST))
# Out:
# <PIL.Image.Image image mode=L size=800x160>

# %%
w, h, f = 64, 48, 2
factor = 10
images = dump("a256_pwsprites.narc")
for img in images:
    display(img.resize((factor*w, factor*h*f), Image.Resampling.NEAREST))
# Out:
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
# <PIL.Image.Image image mode=L size=640x960>
